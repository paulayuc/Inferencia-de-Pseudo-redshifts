# %%
from funciones_ajuste_v2 import *
# Out:
# /home/paulayuc/gbm/lib/python3.10/site-packages/gbm/plot/lal_post_subs.py:184: UserWarning: Basemap not installed. Some functionality not available.
#   warnings.warn('Basemap not installed. Some functionality not available.')

# %%
nombre_grb = "bn090926181"
cspecs, bkgds, rsps = procesar_fondo(nombre_grb, orden=1)
plot_curvas_y_espectros(cspecs, bkgds, nombre_grb)

# %%
ajustemulticomp_grb(nombre_grb, cspecs, bkgds, rsps, margen_error=15)

# %%
z_optimo, pendiente, amplitud = buscar_z_optimo3(nombre_grb, z_steps=300)

# %%
nombre_grb = "bn090902462"
cspecs, bkgds, rsps = procesar_fondo(nombre_grb, orden=1)
plot_curvas_y_espectros(cspecs, bkgds, nombre_grb)

# %%
plot_curvas_y_espectros(cspecs, bkgds, nombre_grb)

# %%
z_optimo, pendiente, amplitud = buscar_z_optimo3(nombre_grb, z_steps=300)

# %%
nombre_grb="bn200829582"
cspecs, bkgds, rsps = procesar_fondo(nombre_grb, orden=1)
plot_curvas_y_espectros(cspecs, bkgds, nombre_grb)

# %%
ajustemulticomp_grb(nombre_grb, cspecs, bkgds, rsps, margen_error=15)

# %%
z_optimo, pendiente, amplitud = buscar_z_optimo3(nombre_grb, z_steps=300)
